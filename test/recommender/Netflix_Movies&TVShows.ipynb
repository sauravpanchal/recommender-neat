# %%
import pandas as pd, numpy as np

# %%
data = pd.read_csv("/content/drive/MyDrive/Datasets/netflix_titles.csv")
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 12 columns]

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.shape
# Out:
# (8807, 12)

# %%
d = data.dropna()

# %%
d.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
d.shape
# Out:
# (5332, 12)

# %%
d.loc[d.title == "Sankofa"]
# Out:
#   show_id  ...                                        description
# 7      s8  ...  On a photo shoot in Ghana, an American model s...
#
# [1 rows x 12 columns]

# %%
d.head()
# Out:
#    show_id  ...                                        description
# 7       s8  ...  On a photo shoot in Ghana, an American model s...
# 8       s9  ...  A talented batch of amateur bakers face off in...
# 9      s10  ...  A woman adjusting to life after a loss contend...
# 12     s13  ...  After most of her family is murdered in a terr...
# 24     s25  ...  When the father of the man she loves insists t...
#
# [5 rows x 12 columns]

# %%
# !pip install neat
# Out:
# Collecting neat
#   Downloading neat-0.4.1.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 5.0 MB/s
# Collecting WebOb
#   Downloading WebOb-1.8.7-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 18.6 MB/s
# Building wheels for collected packages: neat
#   Building wheel for neat (setup.py) ... done
#   Created wheel for neat: filename=neat-0.4.1-py3-none-any.whl size=8078 sha256=84b31a1a70db9d5140b0a060f0e3b0173a3e5798b003796c5df22450a7f8901a
#   Stored in directory: /root/.cache/pip/wheels/12/e6/c7/c5ea0eb2ce1c5f3f4385e9c21b2b2826388aafd029b888d612
# Successfully built neat
# Installing collected packages: WebOb, neat
# Successfully installed WebOb-1.8.7 neat-0.4.1

# %%
import neat

# %%
def run():
  # pass
  config = neat.config.Config
  (
        neat.DefaultGenome,
        neat.DefaultReproduction,
        neat.DefaultSpeciesSet,
        neat.DefaultStagnation,
        config_path,
  )
  
  p = neat.Population(config)

  p.add_reporter(neat.StdOutReporter(True))
  stats = neat.StatisticsReporter()
  p.add_reporter(stats)
  
config_path = "/content/drive/MyDrive/Netflix Movies & TV Shows Recommender - neat-python/feedforward.txt"
run(config_path)
